# %%
# !pip install mlxtend

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

df = pd.read_excel('/content/preprocessed_unigame time.csv.xlsx')
df_cleaned = df.dropna(axis=1, how='all').astype(str)

transactions = df_cleaned.apply(lambda row: [f"{col.strip()}={val.strip()}" for col, val in row.items()], axis=1).tolist()

te = TransactionEncoder()
te_ary = te.fit_transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

rules['antecedent_len'] = rules['antecedents'].apply(lambda x: len(x))
rules = rules[rules['antecedent_len'] >= 2]

rules_cgpa = rules[rules['consequents'].astype(str).str.contains('Your  current CGPA\\? \\(categorical\\)=')].copy()

import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

df = pd.read_excel('/content/preprocessed_unigame time.csv.xlsx')

df_cleaned = df.dropna(axis=1, how='all').astype(str)

transactions = df_cleaned.apply(
    lambda row: [f"{col.strip()}={val.strip()}" for col, val in row.items()],
    axis=1).tolist()

te = TransactionEncoder()
te_ary = te.fit_transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

#Apriori algorithm
frequent_itemsets = apriori(df_encoded, min_support=0.01, use_colnames=True)

#association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# >2 items in antecedent
rules['antecedent_len'] = rules['antecedents'].apply(lambda x: len(x))
rules = rules[rules['antecedent_len'] >= 2]

# CONSEQUENT = "Your current CGPA? (categorical)"
rules_cgpa = rules[
    (rules['consequents'].apply(lambda x: len(x) == 1)) &
    (rules['consequents'].astype(str).str.contains('Your  current CGPA\\? \\(categorical\\)='))].copy()

rules_cgpa['antecedents'] = rules_cgpa['antecedents'].apply(lambda x: ', '.join(sorted(list(x))))
rules_cgpa['consequents'] = rules_cgpa['consequents'].apply(lambda x: ', '.join(sorted(list(x))))

rules_final = rules_cgpa[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
rules_final = rules_final.sort_values(by=['confidence', 'lift'], ascending=False)
rules_final
# Out:
#                                             antecedents  \
# 65    Do you attend your morning class regularly?=No...
# 95    Do you attend your morning class regularly?=Ye...
# 97    Do you attend your morning class regularly?=Ye...
# 121    Do you fill Fatigue?=No, Your  current CGPA?=2.0
# 122    Do you fill Fatigue?=No, Your  current CGPA?=2.5
# ...                                                 ...
# 879   How many time you spend with family and friend...
# 1318  Do you attend your morning class regularly?=Ye...
# 1209  Do you attend your morning class regularly?=No...
# 686   Do you fill Fatigue?=No, The average time you ...
# 1905  Do you attend your morning class regularly?=No...
#
#                                     consequents   support  confidence  \
# 65        Your  current CGPA? (categorical)=Low  0.034378    1.000000
# 95        Your  current CGPA? (categorical)=Low  0.028311    1.000000
# 97        Your  current CGPA? (categorical)=Low  0.013145    1.000000
# ...
